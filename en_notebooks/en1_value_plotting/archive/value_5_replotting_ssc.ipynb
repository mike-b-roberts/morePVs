# %%
import morePVs
import pandas as pd
import morePVs_output

# %%
project = 'EN1_value_of_pv2'
study_name = 'combined_value5'
op=morePVs_output.Output(project = 'EN1_value_of_pv2', study_name = 'combined_value5')

# %%
p = op.plotOutput('scm_ssm_vs_pv')
