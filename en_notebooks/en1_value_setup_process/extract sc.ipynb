# %%
import pandas as pd
import morePVs_output as opm
import morePVs as mpv
import os
import en_utilities as um
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.lines as mlines


f = 'C:\\Users\\z5044992\\Documents\\MainDATA\\DATA_EN_3\\studies\\EN1_value_of_pv2\\outputs\\combined_value6\\combined_value6_results.csv'

# %%
project='EN1_value_of_pv2'
study_name='combined_value6'
base_path='C:\\Users\\z5044992\\Documents\\MainDATA\\DATA_EN_3\\studies'
op = opm.Output(base_path = base_path,
                          project = project,
                          study_name = study_name)

short_name = 'value6'

# %%
self = op
df = self.data.copy()
df_in = self.study_parameters.copy()
df = df.merge(df_in,left_index = True, right_index=True)
for c in df.columns:
    if '_x' in c:
        nc = c[:-2]
        df.rename(columns={c:nc}, inplace=True)
df.head()
# Out:
#             scenario_label arrangement  number_of_households   load_folder  \
# scenario
# A0        siteA_value6_000         bau                 208.0  h_all_site_A
# A1        siteA_value6_001     btm_s_c                 208.0  h_all_site_A
# A2        siteA_value6_002     btm_s_c                 208.0  h_all_site_A
# A3        siteA_value6_003     btm_s_c                 208.0  h_all_site_A
# A4        siteA_value6_004     btm_s_c                 208.0  h_all_site_A
#
#           central_battery_kWh   en_opex  en_capex_repayment  \
# scenario
# A0                        0.0      0.00            0.000000
# A1                        0.0  12514.92        24906.834866
# A2                        0.0  12514.92        14302.993306
# A3                        0.0  12514.92        10871.576287
# A4                        0.0  12514.92         9229.924613
#
#           pv_capex_repayment  average_hh_bill$  average_hh_solar_bill$  \
# scenario
# ...

# %%
sites=['A','E','D','B','H','I','G','C','J','F']

# %%
df['site'] = df['load_folder'].apply(lambda x : x[-1:])
df.head()
# Out:
#             scenario_label arrangement  number_of_households   load_folder  \
# scenario
# A0        siteA_value6_000         bau                 208.0  h_all_site_A
# A1        siteA_value6_001     btm_s_c                 208.0  h_all_site_A
# A2        siteA_value6_002     btm_s_c                 208.0  h_all_site_A
# A3        siteA_value6_003     btm_s_c                 208.0  h_all_site_A
# A4        siteA_value6_004     btm_s_c                 208.0  h_all_site_A
#
#           central_battery_kWh   en_opex  en_capex_repayment  \
# scenario
# A0                        0.0      0.00            0.000000
# A1                        0.0  12514.92        24906.834866
# A2                        0.0  12514.92        14302.993306
# A3                        0.0  12514.92        10871.576287
# A4                        0.0  12514.92         9229.924613
#
#           pv_capex_repayment  average_hh_bill$  average_hh_solar_bill$  ...   \
# ...

# %%
df2=pd.DataFrame()
for s in sites:
    df2.loc[s,'sc_i'] = df.loc[(df['site']==s) & (df['arrangement']=='btm_icp') & (df['pv_cap_id'].str.contains('max')), 'self-consumption_mean'].max()
    
    df2.loc[s,'sc_s'] = df.loc[(df['site']==s) & (df['arrangement']=='btm_s_c') & (df['pv_cap_id'].str.contains('max')), 'self-consumption_mean'].max()

# %%
df2
# Out:
#         sc_i        sc_s
# A  92.772354  100.000000
# E  84.666822  100.000000
# D  93.183119  100.000000
# B  97.177916  100.000000
# H  35.665131   46.365444
# I  51.385719   76.079840
# G  44.276399   62.836940
# C  90.261445  100.000000
# J  43.917634   53.057464
# F  59.294562   74.827885
