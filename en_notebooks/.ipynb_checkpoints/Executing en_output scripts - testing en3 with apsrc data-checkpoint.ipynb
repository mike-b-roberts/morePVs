# %% [markdown]
# ## Executing en_output scripts
# 12/3/18

# %%
from en import en_output1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0d8afb93981d> in <module>()
# ----> 1 from en import en_output1
#
# C:\PYTHONprojects\en\en_output1.py in <module>()
# ----> 1 import matplotlib as mpl
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#       4 import os
#       5 import sys
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
project = 'past_papers'
study_name = 'apsrc2017'
op = en_output1.Output(project = project,
                      study_name = study_name)

# %%
op.csv_output()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-be8445400aa1> in <module>()
# ----> 1 op.csv_output()
#
# NameError: name 'op' is not defined

# %%
op.plot_output()
# Out:
# csv_total_vs_type
# bar_total_vs_site_arrangement
# {'A': 'A(208/12)', 'E': 'E(161/7)', 'D': 'D(138/9)', 'B': 'B(104/8)', 'H': 'H(52/3)', 'I': 'I(48/4)', 'G': 'G(44/44)', 'C': 'C(34/34)', 'J': 'J(26/26)', 'F': 'F(20/5)'}
